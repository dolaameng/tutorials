# %%
# %pylab inline --no-import-all
import pylab as pl
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from datetime import datetime
from sklearn.metrics import r2_score
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Forecasting Method
# - Model Based (*strong assumption, working better when data is sparse*):
#     - multi-regression analysis
#     - autoregression analysis
#     - logistic regression
# - Data Driven:
#     - smoothing method (SES, Holt-Winter)
#     - NN
#     - CART
# - Combination:
#     - ensemble
#     - boosting (ensemble on error)
#
# Model-Based: global trend
#
# Data-Driven: local trend (short memory param) + global trend (long memory param)

# %% [markdown]
# ###1. Regression Based Model
# - linear (exp, poly) regression - **for trend**
# - additive/multiplicative seasonal component - **for seasonal**
# - autoregression for improvement
# - autoregression for forecastability

# %% [markdown]
# #### regression for trend

# %%
def as_yearmon(month_year):
    dt = datetime.strptime(month_year, "%b-%y")
    return pd.Period(year = dt.year, month = dt.month, freq='M')

# %%
amtrack = pd.read_csv("../../data/time-series/Amtrak.csv", )
amtrack = amtrack.iloc[:, :2]
amtrack.Month = map(as_yearmon, amtrack.Month)
amtrack.set_index("Month", inplace=True)

# %%
amtrack.plot()

# %%
X = amtrack.copy()
X['t'] = np.arange(1, X.shape[0]+1)
#X = sm.add_constant(X)
print X.head()
test_X = X.iloc[-12:, :]
train_X = X.iloc[:-12, :]
print train_X.shape, test_X.shape
# Out:
#          Ridership  t
# Month
# 1991-01       1709  1
# 1991-02       1621  2
# 1991-03       1973  3
# 1991-04       1812  4
# 1991-05       1975  5
#
# [5 rows x 2 columns]
# (147, 2) (12, 2)

# %%
## linear regression
model = smf.ols('Ridership ~ t', df = train_X)
model = model.fit()
print model.summary()

print r2_score(train_X.Ridership, model.predict(train_X ))
print r2_score(test_X.Ridership, model.predict(test_X ))

ax = X.Ridership.plot()
ax.plot_date(X.index, model.predict(X), 'r-')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Ridership   R-squared:                       0.090
# Model:                            OLS   Adj. R-squared:                  0.084
# Method:                 Least Squares   F-statistic:                     14.40
# Date:                Mon, 03 Mar 2014   Prob (F-statistic):           0.000217
# Time:                        20:11:48   Log-Likelihood:                -956.67
# No. Observations:                 147   AIC:                             1917.
# Df Residuals:                     145   BIC:                             1923.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   1713.1154     27.083     63.254      0.000      1659.586  1766.644
# t              1.2046      0.317      3.794      0.000         0.577     1.832
# ==============================================================================
# Omnibus:                        5.273   Durbin-Watson:                   1.081
# Prob(Omnibus):                  0.072   Jarque-Bera (JB):                5.400
# Skew:                          -0.456   Prob(JB):                       0.0672
# Kurtosis:                       2.775   Cond. No.                         171.
# ==============================================================================
# 0.0903160184833
# -1.92036771668

# %%
## exp regression
model = smf.ols('np.log(Ridership) ~ t', df = train_X)
model = model.fit()
print model.summary()

print r2_score(train_X.Ridership, np.exp(model.predict(train_X )))
print r2_score(test_X.Ridership, np.exp(model.predict(test_X )))

ax = X.Ridership.plot()
ax.plot_date(X.index, np.exp(model.predict(X)), 'r-')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      np.log(Ridership)   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     12.88
# Date:                Mon, 03 Mar 2014   Prob (F-statistic):           0.000454
# Time:                        20:30:21   Log-Likelihood:                 141.07
# No. Observations:                 147   AIC:                            -278.1
# Df Residuals:                     145   BIC:                            -272.2
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      7.4440      0.015    481.116      0.000         7.413     7.475
# t              0.0007      0.000      3.588      0.000         0.000     0.001
# ==============================================================================
# Omnibus:                       11.184   Durbin-Watson:                   1.076
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.698
# Skew:                          -0.682   Prob(JB):                      0.00288
# Kurtosis:                       3.216   Cond. No.                         171.
# ==============================================================================
# 0.0909380911144
# -2.12202869684

# %%
## poly regression
model = smf.ols('Ridership ~ t + I(t**2)', df = train_X)
model = model.fit()
print model.summary()

print r2_score(train_X.Ridership, model.predict(train_X ))
print r2_score(test_X.Ridership, model.predict(test_X ))

ax = X.Ridership.plot()
ax.plot_date(X.index, model.predict(X), 'r-')

pl.figure()
pl.plot(X.Ridership - model.predict(X), label = 'Residual')
pl.legend()

_ = sm.graphics.tsa.plot_acf(X.Ridership - model.predict(X), lags = 10, )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Ridership   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.221
# Method:                 Least Squares   F-statistic:                     21.74
# Date:                Mon, 03 Mar 2014   Prob (F-statistic):           5.60e-09
# Time:                        20:39:33   Log-Likelihood:                -944.23
# No. Observations:                 147   AIC:                             1894.
# Df Residuals:                     144   BIC:                             1903.
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   1859.2033     37.780     49.211      0.000      1784.528  1933.878
# t             -4.6781      1.179     -3.969      0.000        -7.008    -2.349
# I(t ** 2)      0.0397      0.008      5.153      0.000         0.025     0.055
# ==============================================================================
# Omnibus:                        8.449   Durbin-Watson:                   1.280
# Prob(Omnibus):                  0.015   Jarque-Bera (JB):                7.481
# Skew:                          -0.476   Prob(JB):                       0.0237
# Kurtosis:                       2.439   Cond. No.                     2.97e+04
# ==============================================================================
#
# The condition number is large, 2.97e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 0.231944438549
# -0.246601635642

# %% [markdown]
# *2nd order Polynomial works quite well with trend, but the acf of residuals at lag 6 reveals there is a seasonal part*
#
# *and acf at lag = 1 reveals an autogression model*

# %% [markdown]
# #### use dummy variable to model seasonality

# %%
season = map(lambda t: t.month, X.index)
XX = pd.concat([X, pd.get_dummies(season, prefix="M").set_index(X.index)], axis = 1, )
print XX.shape
print XX.columns

train_X = XX.iloc[:-12, :]
test_X = XX.iloc[-12:, :]
print train_X.shape, test_X.shape
# Out:
# (159, 14)
# Index([u'Ridership', u't', u'M_1', u'M_2', u'M_3', u'M_4', u'M_5', u'M_6', u'M_7', u'M_8', u'M_9', u'M_10', u'M_11', u'M_12'], dtype='object')
# (147, 14) (12, 14)

# %%
## poly regression + season
model = smf.ols('Ridership ~ t + I(t**2) + M_1+M_2+M_3+M_4+M_5+M_6+M_7+M_8+M_9+M_10+M_11+M_12', df = train_X)
model = model.fit()
print model.summary()

print r2_score(train_X.Ridership, model.predict(train_X ))
print r2_score(test_X.Ridership, model.predict(test_X ))

ax = X.Ridership.plot()
ax.plot_date(XX.index, model.predict(XX), 'r-')

pl.figure()
pl.plot(XX.Ridership - model.predict(XX), label = 'Residual')
pl.legend()

_ = sm.graphics.tsa.plot_acf(XX.Ridership - model.predict(XX), lags = 15, )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Ridership   R-squared:                       0.825
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     48.36
# Date:                Mon, 03 Mar 2014   Prob (F-statistic):           6.74e-44
# Time:                        21:47:09   Log-Likelihood:                -835.36
# No. Observations:                 147   AIC:                             1699.
# Df Residuals:                     133   BIC:                             1741.
# Df Model:                          13
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   1730.6598     17.356     99.718      0.000      1696.331  1764.989
# t             -5.2459      0.587     -8.943      0.000        -6.406    -4.086
# I(t ** 2)      0.0437      0.004     11.394      0.000         0.036     0.051
# M_1          -65.1123     19.910     -3.270      0.001      -104.493   -25.732
# M_2         -103.8358     19.915     -5.214      0.000      -143.227   -64.445
# M_3          195.4301     19.922      9.810      0.000       156.026   234.834
# M_4          202.3691     20.688      9.782      0.000       161.449   243.289
# M_5          232.6132     20.692     11.242      0.000       191.685   273.541
# M_6          190.2699     20.697      9.193      0.000       149.333   231.207
# M_7          293.7557     20.702     14.190      0.000       252.809   334.703
# M_8          337.6540     20.707     16.306      0.000       296.696   378.612
# M_9            3.2982     20.713      0.159      0.874       -37.672    44.268
# M_10         141.5215     20.720      6.830      0.000       100.539   182.504
# M_11         130.0740     20.727      6.276      0.000        89.077   171.071
# M_12         172.6223     20.735      8.325      0.000       131.610   213.634
# ==============================================================================
# Omnibus:                        8.197   Durbin-Watson:                   0.699
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):                8.158
# Skew:                          -0.570   Prob(JB):                       0.0169
# Kurtosis:                       3.173   Cond. No.                          nan
# ==============================================================================
#
# The smallest eigenvalue is -1.32e-14. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.825375985102
# 0.83028033403

# %% [markdown]
# *Now we only got autocorrelation left in the residual*

# %%
## or use sin/cos to approximate continous seasonality function
model = smf.ols('Ridership ~ t + I(t**2) + np.sin(np.pi*2*t/52.18) + np.cos(np.pi*2*t/52.18)', df = train_X)
model = model.fit()
print model.summary()

print r2_score(train_X.Ridership, model.predict(train_X ))
print r2_score(test_X.Ridership, model.predict(test_X ))

ax = X.Ridership.plot()
ax.plot_date(X.index, model.predict(X), 'r-')

pl.figure()
pl.plot(X.Ridership - model.predict(X), label = 'Residual')
pl.legend()

_ = sm.graphics.tsa.plot_acf(X.Ridership - model.predict(X), lags = 15, )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Ridership   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.217
# Method:                 Least Squares   F-statistic:                     11.13
# Date:                Mon, 03 Mar 2014   Prob (F-statistic):           7.02e-08
# Time:                        21:04:47   Log-Likelihood:                -943.59
# No. Observations:                 147   AIC:                             1897.
# Df Residuals:                     142   BIC:                             1912.
# Df Model:                           4
# =================================================================================================
#                                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------------
# Intercept                      1860.9253     38.440     48.412      0.000      1784.937  1936.913
# t                                -4.6619      1.188     -3.923      0.000        -7.011    -2.313
# I(t ** 2)                         0.0392      0.008      5.053      0.000         0.024     0.055
# np.sin(np.pi * 2 * t / 52.18)    -5.8598     17.835     -0.329      0.743       -41.117    29.397
# np.cos(np.pi * 2 * t / 52.18)   -19.2109     18.105     -1.061      0.290       -55.001    16.579
# ==============================================================================
# Omnibus:                        8.784   Durbin-Watson:                   1.292
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                7.736
# Skew:                          -0.484   Prob(JB):                       0.0209
# Kurtosis:                       2.430   Cond. No.                     3.02e+04
# ==============================================================================
#
# The condition number is large, 3.02e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 0.238656987531
# -0.191247093383
