# %%
import networkx as nx
# %matplotlib inline
import pylab as pl

# %%
g = nx.read_edgelist("data/facebook/0.edges")

# %%
nx.draw_networkx(g, edge_color='y', with_labels=False, node_size=15, node_color='y', alpha=.4)
