# %% [markdown]
# # Local Image Descriptors

# %% [markdown]
# ***Finding Corresponding points and regions BETWEEN images***
#
# - Harris corner detetor
# - SIFT - Scale-Invariant Feature Transform
#
# These local features will be used in many different contexts throughout this book and are an important building block in many applications such as creating panoramas, augmented reality, and computing 3D reconstructions.

# %% [markdown]
# ***Harris corner detector***
#
# - The Harris corner detection algorithm (or sometimes the Harris & Stephens corner detector) is one of the simplest corner indicators available
# - The general idea is to locate interest points where the surrounding neighborhood shows edges in more than one direction, these are then image corners
# - Implemented in skimage.feature package - three step process:
#     - (1) use corner detector to find `response` image,
#     - (2) use `corner_peaks` or `peak_local_max` to find coordinates or boolean array of corners
#     - (3) OPTIONALLY, use `corner_subpix` to determine the subpixel corner positions
# - **NOTE that the corners found are in [[row, col]...] format, which corresponds to [[y, x], ...] coordidate in drawing**

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
from skimage import color, io, feature

## Original Image
img = color.rgb2gray(io.imread('data/python-cv/empire.jpg'))
## Harris corner response
harris_response = feature.corner_harris(img, sigma = 1.5, )
## corners with different thresholds
## NOTE THAT rows -- ys and cols -- xs
ys_small, xs_small = zip(*feature.corner_peaks(harris_response, threshold_rel=0.01, ))
ys_big, xs_big = zip(*feature.corner_peaks(harris_response, threshold_rel=0.1))
## Plot images
fig, axes = subplots(nrows = 2, ncols = 2, figsize=(12, 12))
gray()
axes[0, 0].imshow(img)
axes[0, 0.].set_title('original image')
axes[0, 1].imshow(harris_response)
axes[0, 0.].set_title('harris response')
axes[1, 0].imshow(img)
axes[1, 0].plot(xs_small, ys_small, 'b+')
axes[1, 0.].set_title('harris corners $thr=0.01$')
axes[1, 0].axis('off')
axes[1, 1].imshow(img)
axes[1, 1].plot(xs_big, ys_big, 'b+')
axes[1, 1.].set_title('harris corners $thr=0.1$')
axes[1, 1].axis('off')
# Out:
# (-100.0, 600.0, 800.0, -100.0)

# %% [markdown]
# ***Decriptors for Corners***
#
# - The Harris corner detector gives interest points in images but does not contain an inherent way of comparing these interest points across images to find matching corners.
# - What we need is to add a descriptor to each point and a way to compare such descriptors.
# - An **interest point descriptor** is a vector assigned to an interest point that describes the image appearance around the point.
# - With point correspondence or corresponding points we mean points in different images that refer to the same object or scene point. The better the descriptor, the better your correspondences will be.

# %% [markdown]
# ***Robust matching using RANSAC***
#
# - Steps:
#     - (1) Find interest points in two correlated images (based on harris descriptors)
#     - (2) Find correspondences based on weighted sum of squared differences of a small neighborhood around them (patches)
#     - (3) After finding the correspondences we end up having a set of source and destination coordinates which can be used to `estimate the geometric transformation` between both images
#     - (4) Therefore, the RANSAC algorithm is used on top of the normal model to robustly estimate the parameter set by detecting outliers.
# -  Note, that this measure is only robust towards linear radiometric and not geometric distortions and is thus only usable with slight view point changes.
#
# Examples from http://scikit-image.org/docs/dev/auto_examples/plot_matching.html

# %%
## The check board example from skimage
from skimage import data, feature, transform, color
from skimage import exposure, measure

checkboard = data.checkerboard()

# %% [markdown]
# ***SIFT Descriptor***

# %%
import cv2

img = cv2.imread('data/python-cv/empire.jpg')
detector = cv2.FeatureDetector_create('SIFT')
extractor = cv2.DescriptorExtractor_create('SIFT')
keypoints = detector.detect(img)
descriptions = extractor.compute(img, keypoints)

# %%
## DAISY descriptors
img = color.rgb2gray(io.imread('data/python-cv/empire.jpg'))
descs, descs_img = feature.daisy(img, visualize=True, step = 180, radius = 58)
imshow(descs_img)
print descs.shape
print descs.flatten().shape
# Out:
# (4, 3, 200)
# (2400,)

# %% [markdown]
# ***Clustering of Geotagged Images***
#
# Panoramio Service API: http://www.panoramio.com/map/get_panoramas.php?order=popularity&set=public&from=0&to=20&minx=-180&miny=-90&maxx=180&maxy=90&size=medium
#
#
# White house images: http://www.panoramio.com/map/get_panoramas.php?order=popularity&set=public&from=0&to=20&minx=-77.037564&miny=38.896662&maxx=-77.035564&maxy=38.898662&size=medium

# %%
from os import path
import os

# %%
## download images
import json, urllib, urlparse, os
from os import path
images_url = 'http://www.panoramio.com/map/get_panoramas.php?order=popularity&set=public&from=0&to=20&minx=-77.037564&miny=38.896662&maxx=-77.035564&maxy=38.898662&size=medium'
conn = urllib.urlopen(images_url)
content = json.loads(conn.read())
imurls = [im['photo_file_url'] for im in content['photos']]
## download images
if not path.exists('data/python-cv/downloaded'):
    os.mkdir('data/python-cv/downloaded')
for imurl in imurls:
    filename = path.join('data/python-cv/downloaded', path.basename(urlparse.urlparse(imurl).path))
    img = urllib.URLopener()
    img.retrieve(imurl, filename)
    print 'downloading:', imurl
# Out:
# downloading: http://mw2.google.com/mw-panoramio/photos/medium/43112658.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/588922.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/17651545.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/3725907.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/17651671.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/13512111.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/5752686.jpg
# downloading: http://mw2.google.com/mw-panoramio/photos/medium/42746486.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/42748461.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/13336115.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/9309411.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/47241262.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/3128351.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/17651715.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/2065261.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/31182283.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/17651631.jpg
# downloading: http://mw2.google.com/mw-panoramio/photos/medium/37130987.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/7437413.jpg
# downloading:
#  http://mw2.google.com/mw-panoramio/photos/medium/24265229.jpg

# %%
from IPython.parallel import Client
client = Client()
print len(client)
dv = client[:]
dv.block = True
dv.execute('from functools import partial')
# Out:
# 24
# <AsyncResult: finished>

# %%
## get DAISY descriptors
# %%px
def get_daisy_descriptors(img, step=180, radius=58):
    from skimage import color, feature
    img = color.rgb2gray(img)
    descs = feature.daisy(img, step = step, radius = radius)
    return descs.flatten()

# %%
img = io.imread('data/python-cv/downloaded/5752686.jpg')
descs = get_daisy_descriptors(img)
print descs.shape
# Out:
# (1200,)

# %%
whitehouses = [io.imread(path.join('data/python-cv/downloaded/', f)) 
        for f in os.listdir('data/python-cv/downloaded/')]

desc_vectors = dv.map(get_daisy_descriptors, whitehouses)

# %%
print [v.shape for v in desc_vectors]
wh_X = np.vstack(desc_vectors)
print wh_X.shape
# Out:
# [(1200,), (1200,), (1200,), (1200,), (1200,), (1200,), (1200,), (1200,), (1200,), (1200,), (1200,), (1200,), (1200,), (1200,), (1200,), (1200,), (1200,), (1200,), (1200,), (1200,)]
# (20, 1200)

# %%
from sklearn import metrics
dist_X = metrics.pairwise.euclidean_distances(wh_X, )
print dist_X.shape
# Out:
# (20, 20)

# %%
print np.min(dist_X), np.max(dist_X), np.mean(dist_X)
# Out:
# 0.0 0.225484671959 0.143878360952

# %%
print dist_X
# Out:
# [[ 0.          0.20052238  0.08199398  0.05591086  0.14601072  0.0686533
#    0.17549227  0.13094726  0.20023343  0.12483177  0.11675625  0.09309713
#    0.16643728  0.1487935   0.1086452   0.07905726  0.11748645  0.15809533
#    0.17963316  0.17879453]
#  [ 0.20052238  0.          0.19769775  0.19730203  0.17735927  0.20243065
#    0.17720715  0.16645365  0.10606373  0.16550483  0.20529454  0.19474267
#    0.18670004  0.19800462  0.22548467  0.2029362   0.19476433  0.17766514
#    0.13958507  0.16989988]
#  [ 0.08199398  0.19769775  0.          0.0615181   0.14019278  0.06490658
#    0.16849089  0.11960777  0.19088503  0.13758794  0.12392817  0.0800372
#    0.15427998  0.15236103  0.13568219  0.07247947  0.10446833  0.14781205
#    0.1762194   0.18039373]
#  [ 0.05591086  0.19730203  0.0615181   0.          0.12804476  0.05401759
#    0.16668269  0.12246948  0.19166899  0.12634438  0.11416536  0.07754429
#    0.15453827  0.14634489  0.11865768  0.06198958  0.10876804  0.14466236
#    0.17187939  0.17160755]
#  [ 0.14601072  0.17735927  0.14019278  0.12804476  0.          0.13655911
#    0.17594657  0.12018583  0.14964909  0.16484499  0.17387106  0.13721179
#    0.1670774   0.15460394  0.1689806   0.146915    0.13332436  0.12384007
#    0.16498615  0.14185717]
#  [ 0.0686533   0.20243065  0.06490658  0.05401759  0.13655911  0.
#    0.17310524  0.12159508  0.19885686  0.12622359  0.12505465  0.07632767
#    0.16408268  0.14508783  0.12500569  0.07368501  0.10184294  0.14966008
#    0.1758242   0.178728  ]
#  [ 0.17549227  0.17720715  0.16849089  0.16668269  0.17594657  0.17310524
#    0.          0.15889407  0.15685457  0.14737394  0.16268225  0.15225011
#    0.16246654  0.21667409  0.20802943  0.15927896  0.1503819   0.18680116
#    0.16083934  0.16680576]
#  [ 0.13094726  0.16645365  0.11960777  0.12246948  0.12018583  0.12159508
#    0.15889407  0.          0.15562671  0.15146844  0.15895904  0.12460877
#    0.1576603   0.13160306  0.15893174  0.12446778  0.10865013  0.11430052
#    0.13218176  0.11345537]
#  [ 0.20023343  0.10606373  0.19088503  0.19166899  0.14964909  0.19885686
#    0.15685457  0.15562671  0.          0.16854358  0.20829308  0.18688723
#    0.18490485  0.20669721  0.21938831  0.19382629  0.18242666  0.17733065
#    0.12726769  0.1595478 ]
#  [ 0.12483177  0.16550483  0.13758794  0.12634438  0.16484499  0.12622359
#    0.14737394  0.15146844  0.16854358  0.          0.14058542  0.12445396
#    0.18064591  0.17999166  0.16666487  0.1281804   0.14316756  0.17735705
#    0.16027675  0.17508002]
#  [ 0.11675625  0.20529454  0.12392817  0.11416536  0.17387106  0.12505465
#    0.16268225  0.15895904  0.20829308  0.14058542  0.          0.125689
#    0.1296112   0.18680934  0.17310464  0.11083209  0.15100681  0.17490562
#    0.18920925  0.19078418]
#  [ 0.09309713  0.19474267  0.0800372   0.07754429  0.13721179  0.07632767
#    0.15225011  0.12460877  0.18688723  0.12445396  0.125689    0.
#    0.15551666  0.1572285   0.14321843  0.08386899  0.09665447  0.14919924
#    0.15883557  0.16611249]
#  [ 0.16643728  0.18670004  0.15427998  0.15453827  0.1670774   0.16408268
#    0.16246654  0.1576603   0.18490485  0.18064591  0.1296112   0.15551666
#    0.          0.19815898  0.20998914  0.15995508  0.17154066  0.14837554
#    0.17438491  0.17137675]
#  [ 0.1487935   0.19800462  0.15236103  0.14634489  0.15460394  0.14508783
#    0.21667409  0.13160306  0.20669721  0.17999166  0.18680934  0.1572285
#    0.19815898  0.          0.16731473  0.16427732  0.15621784  0.13506063
#    0.16499557  0.15668033]
#  [ 0.1086452   0.22548467  0.13568219  0.11865768  0.1689806   0.12500569
#    0.20802943  0.15893174  0.21938831  0.16666487  0.17310464  0.14321843
#    0.20998914  0.16731473  0.          0.13546304  0.14523416  0.19043787
#    0.20817158  0.2013723 ]
#  [ 0.07905726  0.2029362   0.07247947  0.06198958  0.146915    0.07368501
#    0.15927896  0.12446778  0.19382629  0.1281804   0.11083209  0.08386899
#    0.15995508  0.16427732  0.13546304  0.          0.11191498  0.16368843
#    0.17343018  0.17610912]
#  [ 0.11748645  0.19476433  0.10446833  0.10876804  0.13332436  0.10184294
#    0.1503819   0.10865013  0.18242666  0.14316756  0.15100681  0.09665447
#    0.17154066  0.15621784  0.14523416  0.11191498  0.          0.14843117
#    0.16517411  0.15600941]
#  [ 0.15809533  0.17766514  0.14781205  0.14466236  0.12384007  0.14966008
#    0.18680116  0.11430052  0.17733065  0.17735705  0.17490562  0.14919924
#    0.14837554  0.13506063  0.19043787  0.16368843  0.14843117  0.
#    0.14474426  0.11817644]
#  [ 0.17963316  0.13958507  0.1762194   0.17187939  0.16498615  0.1758242
#    0.16083934  0.13218176  0.12726769  0.16027675  0.18920925  0.15883557
#    0.17438491  0.16499557  0.20817158  0.17343018  0.16517411  0.14474426
#    0.          0.12198166]
#  [ 0.17879453  0.16989988  0.18039373  0.17160755  0.14185717  0.178728
#    0.16680576  0.11345537  0.1595478   0.17508002  0.19078418  0.16611249
#    0.17137675  0.15668033  0.2013723   0.17610912  0.15600941  0.11817644
#    0.12198166  0.        ]]

# %%
whitehouses[1]
# Out:
# Image([[[150, 200, 235],
#         [150, 200, 235],
#         [148, 201, 235],
#         ...,
#         [130, 186, 221],
#         [130, 186, 221],
#         [130, 186, 221]],
#
#        [[150, 200, 235],
#         [150, 200, 235],
#         [148, 201, 235],
#         ...,
#         [132, 186, 224],
#         [132, 186, 224],
#         [131, 185, 223]],
#
#        [[148, 201, 235],
#         [148, 201, 235],
#         [148, 201, 235],
#         ...,
#         [132, 186, 224],
#         [132, 186, 224],
#         [132, 186, 224]],
#
#        ...,
#        [[ 96, 115,  60],
#         [ 89, 108,  53],
#         [ 99, 120,  64],
#         ...,
#         [104, 129,  71],
#         [ 95, 120,  62],
#         [104, 129,  71]],
#
#        [[102, 121,  66],
#         [102, 121,  66],
#         [103, 122,  67],
#         ...,
#         [ 95, 119,  59],
#         [ 95, 119,  59],
#         [103, 127,  67]],
#
#        [[135, 154,  99],
#         [121, 140,  85],
#         [ 98, 116,  64],
#         ...,
#         [ 99, 121,  57],
#         [105, 127,  63],
#         [ 98, 120,  56]]], dtype=uint8)

# %%
from sklearn import cluster
kmeans = cluster.KMeans(n_clusters=5)
kmeans.fit(wh_X)
labels = np.unique(kmeans.labels_)
print len(labels), 'clusters'
## IMAGES: whitehouses
for label in labels:
    figure()
    index = [i for (i, lab) in enumerate(kmeans.labels_) if label ==lab]
    print index
    fig, axes = subplots(ncols = len(index), nrows = 1, figsize=(6, 6))
    #print list(enumerate(index))
    for (ii, i) in enumerate(index):
        #print 'ii', ii
        try:
            axes[ii].imshow(whitehouses[i])
        except:
            axes.imshow(whitehouses[i])
# Out:
# 5 clusters
# [0, 2, 3, 5, 9, 11, 14, 15, 16]
# [1, 8, 18]
# [4, 7, 13, 17, 19]
# [6]
# [10, 12]
